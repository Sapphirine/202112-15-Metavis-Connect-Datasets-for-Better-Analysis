# %%
# !pip install geopandas -U -q
# !pip install pydeck -U -q

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import geopandas as gpd
import pandas as pd
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_colwidth', 100)
import numpy as np
import re
from glob import glob

# %%
metadata_df = pd.read_csv('/content/drive/MyDrive/metavis/socrata_nycopendata_metadata_fetched_20211105.csv')

# %%
geo_data_paths = sorted(glob('/content/drive/MyDrive/metavis/data/*.geojson'))

# %%
p = geo_data_paths[3]
data_uuid = re.findall(r'\/data\/(.*?)\.geojson',p)[0]
print('data_uuid:',data_uuid)
metadata_df.loc[metadata_df['data_uuid']==data_uuid,['name','description','data_page_url']]
# Out:
# data_uuid: 2de2-6x2h
#                            name  \
# 43  Bi-Annual Pedestrian Counts
#
#                                                                                             description  \
# 43  An index of pedestrian volumes tracking the long-term trends of neighborhood commercial corridor...
#
#                                                                          data_page_url
# 43  https://data.cityofnewyork.us/Transportation/Bi-Annual-Pedestrian-Counts/2de2-6x2h

# %%
gdf = gpd.read_file(p)
gdf
# Out:
#     may_21_md sept_09_am may_17_md                          street_nam  \
# 0        1710        991      2776                            Broadway
# 1        1410       1227      2143                   East 161st Street
# 2        4402       2387      6499                   East Fordham Road
# 3        1161       2097      1123                  East Gun Hill Road
# 4        1384        912      2526                 East Tremont Avenue
# ..        ...        ...       ...                                 ...
# 109       131        214       237               Madison Avenue Bridge
# 110        49        138       185                 Third Avenue Bridge
# 111        59         66       144                Willis Avenue Bridge
# 112        37         20         5  Triborough Bridge (Manhattan span)
# 113       353         43       312                 Wards Island Bridge
#
#     may_08_pm may_18_pm sept_07_pm may_16_md         from_stree may_09_md  \
# ...
